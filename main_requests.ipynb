# %%
# -*- coding: UTF-8 -*-
import requests
import json

# %%
headers = {
    'accept': 'application/json',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'ca-ES,ca;q=0.9,es;q=0.8,en;q=0.7,gl;q=0.6,fr;q=0.5,la;q=0.4,da;q=0.3',
    'Connection': 'keep-alive',
    'Content-Length': '306',
    'content-type': 'application/x-www-form-urlencoded',
    'Host': 'bewoyx1cf1-dsn.algolia.net',
    'Origin': 'https://www.pccomponentes.com',
    'Referer': 'https://www.pccomponentes.com/',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'cross-site',
    'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.149 Safari/537.36',
}



url = ' https://bewoyx1cf1-dsn.algolia.net/1/indexes/*/queries?x-algolia-agent=Algolia%20for%20vanilla%20JavaScript%20(lite)%203.32.0%3Binstantsearch.js%203.0.0%3BJS%20Helper%202.26.1&x-algolia-application-id=BEWOYX1CF1&x-algolia-api-key=47978d8b445ceaceb718dd842d434099&x-algolia-usertoken=anonymous-8d3af9c1-5065-4f84-81fd-3c271a5c3e7d'

busqueda = input()
busqueda = busqueda.replace(' ', '%20')


for n in range(10):

    data = {
        "requests": [{
            "indexName":"pccomponentes:es",
            "params":"query="+busqueda+"&maxValuesPerFacet=20&page="+str(n+1)+"&highlightPreTag=ais-highlight__&highlightPostTag=%2Fais-highlight__&clickAnalytics=true&enablePersonalization=true&facets=%5B%22price.amount%22%2C%22brand.name%22%2C%22family.name%22%5D&tagFilters=",
        }]
    }

    r = requests.post(url, data=json.dumps(data), headers=headers)
    response = json.loads(r.content)
    
    resultados = response['results'][0]['hits']
    print(len(resultados))
    for resultado in resultados:
        print(resultado['title'])
        print(resultado['price']['amount'])
# Out:
#  logitech
# 30
# Logitech G635 Auriculares Gaming LightSync 7.1
# 115.99
# Logitech Wireless Mouse M280
# 21.99
# Logitech G203 Lightsync 2nd Gen Ratón Gaming 8000DPI RGB Blanco
# 39.99
# Logitech G840 XL Alfombrilla Gaming
# 39.99
# Logitech G512 Carbon Teclado Mecánico Gaming RGB GX Brown
# 99.99
# Logitech B100 Ratón Blanco
# 5.99
# Logitech G502 Lightspeed Ratón Gaming Inalámbrico 16000DPI
# 123.99
# Logitech MX Keys Teclado Inalámbrico Avanzado Grafito
# 115
# Logitech Pebble M350 Ratón Óptico Inalámbrico Blanco
# 19.99
# Logitech MK850 Combo + Ratón Inalámbrico
# 89.99
# Logitech G305 LightSpeed Ratón Inalámbrico Gaming 12000DPI Negro
# 62.99
# Logitech G440 Alfombrilla Gaming Negra
# 24.99
# Logitech G703 Lightspeed Ratón Inalámbrico Gaming 16000DPI
# 89.99
# Logitech Z333 Speaker 80W
# 59.99
# Logitech G915 Teclado Mecánico Gaming Inalámbrico RGB GL Táctil
# 199
# Logitech Driving Force Shifter
# 49.99
# Logitech M330 Silent Plus Ratón Inalámbrico Negro 1000DPI
# 23.99
# Logitech Wireless Mouse M171 Rojo
# 10.9
# Logitech Z533 Multimedia Speaker System
# 89
# Logitech MX Vertical Ratón Ergonómico Avanzado
# 83.99
# Logitech G920 Driving Force para Xbox One/PC
# 298.99
# Logitech G815 Teclado Mecánico Gaming RGB GL Táctil
# 154.99
# Logitech G604 LightSpeed Ratón Gaming Inalámbrico 16000DPI
# 79.99
# Logitech MX Anywhere 2S Ratón Inalámbrico Negro 4000DPI
# 69.99
# Logitech G Pro Ratón Gaming RGB 16000DPI Negro
# 73.99
# Logitech G Pro Ratón Gaming Inalámbrico 16000DPI Negro
# 128.789
# Logitech Crayon Lápiz Digital para iPad (Desde 2018)
# 61.99
# Logitech HD Pro Webcam C920
# 189
# Logitech Group Sistemas de Videoconferencia
# 998.99
# Logitech Slim Folio Funda con Teclado Bluetooth Gris para iPad 2019 10.2"
# 81
# 30
# Logitech K380 Teclado Bluetooth Multi-Device Blanco
# 47.28
# Logitech Pro Personal Video Collaboration Kit de Videoconferencia
# 379
# Logitech Webcam BCC950
# 329
# Logitech Wireless Combo MK220 Teclado + Ratón Negro (Portugal)
# 23.98
# Logitech Universal Folio Funda con Teclado Inalámbrico para Tablets de 9 a 10"
# 49.99
# Logitech M220 Silent Ratón Wireless Negro
# 19.99
# Logitech G903 Lightspeed Ratón Gaming Inalámbrico 12000DPI
# 119.98
# Logitech Z625 Powerful THX Sound
# 158.99
# Logitech MX Master 3 Ratón Inalámbrico Avanzado 4000DPI Gris
# 104.99
# Logitech Z150 Multimedia Speakers
# 29.18
# Logitech Wireless Combo MK235 (Portugal)
# 25.98
# Logitech Z337 Bold Sound Altavoces Bluetooth Multimedia Negro
# 69.99
# Logitech MX Ergo Trackball Inalámbrico
# 89.99
# Logitech Keyboard K120 Negro (USA)
# 11.98
# Logitech Personal Video Collaboration Kit de Videoconferencia
# 233
# Logitech Z207 Altavoces Bluetooth 2.0
# 39.98
# Logitech G513 Carbon Teclado Mecánico Gaming RGB GX Brown
# 139.98
# Logitech Slim Folio Funda con Teclado Bluetooth Qwerty Español Negro para iPad 2017/2018
# 85.78
# Logitech M720 Triathlon Ratón Inalámbrico Negro  1000DPI
# 45
# Logitech Slim Folio Pro Funda con Teclado para Apple iPad Pro 11"
# 99.99
# Logitech MX518 Ratón Gaming 16000DPI
# 49.99
# Logitech Z150 Multimedia Speakers Blancos
# 40.99
# Logitech G513 Teclado Mecánico Gaming Retroiluminado Switch GX Blue
# 158.99
# Logitech Desktop MK120 Ratón + Teclado Portugués
# 18.98
# Auriculares Estéreo Logitech H111 Negro
# 84.47
# Logitech Slim Combo Funda Azul con Teclado para iPad Pro 12.9"
# 118.99
# Logitech Rugged Folio Funda con Teclado Bluetooth Gris para iPad 2019 10.2"
# 109.99
# Logitech G413 Teclado Mecánico Gaming (Portugués)
# 81
# Logitech Pebble M350 Ratón Óptico Inalámbrico Rosa
# 23
# Logitech K380 Teclado Bluetooth Multi-Device Rosa
# 47.28
# 30
# Logitech M590 Silent Ratón Inalámbrico Negro 1000DPI
# 40.99
# Logitech Wireless Combo MK270 (Portugal)
# 32.98
# Logitech G502 Special Edition Ratón Gaming 16000DPI
# 91.58
# Logitech G613 Teclado Mecánico Gaming Inalámbrico (USA)
# 129.99
# Logitech Wireless Mouse M171 Azul
# 10.99
# Logitech Wireless Mouse USB Rojo
# 20.99
# Logitech Zone Wireless Auriculares Bluetooth con Micrófono
# 189.99
# Logitech R500 Presentador Láser Inalámbrico y USB Negro
# 25.99
# Logitech Slim Folio Funda con Teclado Bluetooth Qwerty Español Negro para iPad Air (3ª generación)
# 87.85
# Logitech H650e Auriculares con Micrófono Negro
# 69.97
# Logitech M100 USB
# 16.32
# Logitech Slim Combo Funda con Teclado Inalámbrico Negro para iPad Pro de 12.9"
# 154.99
# Logitech Stereo Headset H110
# 16.99
# Logitech Desktop MK120 Ratón + Teclado (USA)
# 18.98
# Logitech G Saitek X52 Flight Control System Sistema de Control de Vuelo
# 120
# Logitech MX Master 3 Ratón Inalámbrico Avanzado 4000DPI Negro
# 109
# Logitech PTZ Pro 2 Cámara Web Profesional FullHD
# 769
# Logitech Z607 Altavoces 5.1 Sonido Envolvente 80W
# 125.99
# Logitech Slim Combo Funda Azul con Teclado para iPad Pro 10.5"
# 114
# Logitech G PRO X Auriculares Gaming 7.1
# 170.88
# Logitech R500 Presentador Láser Inalámbrico y USB Gris
# 25.99
# Logitech MeetUp Cámara Web Profesional para Streaming Ultra HD 4K
# 1128.98
# Logitech G920 Driving Force para Xbox One/PC + Wheel Stand Pro Deluxe For Logitech G25/G27/G29/G920
# 399
# Logitech M105 Ratón Óptico 1000DPI Azul
# 16.85
# Logitech MX Anywhere 2S Ratón Inalámbrico Azul 4000DPI
# 73.99
# Logitech Zone Wired Auriculares USB con Micrófono y Cable con Audio Premium
# 113.99
# Logitech Trackman Marble Ratón Ambidiestro
# 47.26
# Logitech G305 LightSpeed Ratón Inalámbrico Gaming 12000DPI Blanco
# 69.99
# Logitech Zone Wireless Plus Auriculares con Micrófono Bluetooth
# 239
# Logitech G Saitek Pro Flight Panel de Radio
# 99.99
# 30
# Logitech M220 Silent Ratón Wireless Rojo
# 22.26
# Logitech G703 Lightspeed Ratón Inalámbrico Gaming 16000DPI Reacondicionado
# 75.85
# Logitech Doodle Collection M238 Ratón Inalámbrico Ambidiestro 1000DPI Rojo
# 26.74
# Logitech Rally Kit de Videoconferencia
# 2500.16
# Logitech Doodle Collection M238 Ratón Inalámbrico Ambidiestro 1000DPI Gris
# 26.05
# Logitech Slim Folio Pro Funda con Teclado para Apple iPad Pro 11" Reacondicionado
# 86.9
# Logitech K400+ Wireless Touch Keyboard Preto (PT)
# 48.88
# Logitech M535 Ratón Bluetooth Ambidiestro 1000DPI Gris
# 46.12
# Logitech M105 Ratón Óptico 1000DPI Blanco
# 18.04
# Logitech M238 Fan Collection Alemania Ratón Inalámbrico 1000DPI
# 26.36
# Logitech G602 Ratón Gaming Inalámbrico
# 71.64
# Logitech C922 Pro Stream
# 89.99
# Logitech P710E Altavoz Portátil USB/Bluetooth/NFC Negro
# 133.12
# Logitech R700 Presentador Inalámbrico
# 66.98
# Logitech M590 Multi-Device Silent Ratón Inalámbrico 1000DPI Gris
# 45.04
# Logitech Spotlight Mando para Presentaciones Inalámbrico Gris
# 102
# Logitech K400+ Wireless Touch Keyboard Blanco
# 37.03
# Logitech Wireless Solar Keyboard K750
# 81
# Logitech M238 Fan Collection Agentina Ratón Inalámbrico 1000DPI
# 26.72
# Logitech G560 Altavoces Gaming 2.1 con Iluminación RGB Lightsync 120W RMS
# 263.8
# Logitech M330 Silent Plus Ratón Inalámbrico Azul 1000DPI
# 40.93
# Logitech Rally Cámara PTZ para Videoconferencias 4K UltraHD
# 1410.71
# Logitech Tap Riser Mount Kit de Montaje para Controlador de Videoconferencia para Logitech Tap
# 216
# Logitech Pro Flight Switch Panel de Mandos de Vuelo
# 86.73
# Logitech M535 Ratón Bluetooth Ambidiestro 1000DPI Azul
# 39.78
# Logitech Slim Combo Funda con Teclado Inalámbrico Negro para iPad Pro de 9.7"
# 136.57
# Logitech M238 Fan Collection Portugal Ratón Inalámbrico 1000DPI
# 29.24
# Logitech M238 Fan Collection Brasil Ratón Inalámbrico 1000DPI
# 24.55
# Logitech M590 Multi-Device Silent Ratón Inalámbrico 1000DPI Rojo
# 48.2
# Logitech G613 Teclado Gaming Mecánico Inalámbrico (UK)
# 171.16
# 30
# Logitech MX Anywhere 2S Ratón Inalámbrico Gris 4000DPI
# 81.69
# Logitech MX Master 2S Ratón Inalámbrico Gris 1000DPI
# 136.18
# Logitech Spotlight Mando para Presentaciones Inalámbrico Oro
# 87.71
# Logitech HD Webcam C930e
# 269
# Logitech K380 Teclado Bluetooth Multi-Device Negro
# 49.99
# Logitech G810 Orion Spectrum RGB
# 138.99
# Logitech G933 Artemis Spectrum Gaming 7.1 Inalámbricos Reacondicionado
# 143.05
# Logitech HD Pro Webcam C920 2.0 Reacondicionado
# 66.8
# Logitech G640 Large Cloth Gaming Mouse Pad
# 34.99
# Logitech G633 Artemis Spectrum Gaming Surround Sound 7.1
# 105
# Logitech ConferenceCam Connect
# 430
# Logitech M560 Ratón Wireless Negro
# 36.99
# Logitech G430 Gaming Surround Sound 7.1
# 69.99
# Logitech Gamepad F710 Wireless
# 33.99
# Logitech Wireless Combo MK270 Teclado Inalámbrico
# 26.98
# Logitech H340 Headset USB
# 68.99
# Logitech Wireless Combo MK330
# 44.99
# Logitech Wireless Keyboard K270 Negro
# 27
# Logitech Wireless Mouse M185 Gris
# 10.9
# Logitech S120 Speaker System
# 13.99
# Logitech Stereo Speakers Z120
# 18.98
# Logitech Wireless Mini Mouse M187 Negro
# 13.99
# Logitech Wireless Combo MK220 Teclado + Ratón
# 20.9
# Logitech Speaker System Z906 500W 5.1 THX Digital
# 298.99
# Logitech Keyboard K120 Teclado USB
# 9.98
# Logitech Desktop MK120
# 16.99
# Logitech Wireless Trackball M570
# 67.99
# Logitech Marathon Mouse M705 Ratón Inalámbrico Láser
# 37.98
# Logitech Gamepad F310
# 21.99
# Logitech HD Webcam C310
# 64.989
# 30
# Logitech Wireless Illuminated Keyboard K800
# 89.99
# Logitech Z623 Altavoces con Subwoofer 200W RMS
# 144.99
# Logitech HD Webcam C270
# 75
# Logitech Surround Sound Speakers Z506 5.1
# 115.99
# Logitech Speaker System Z313 Altavoces 2.1
# 40.99
# Logitech Speakers Z130 2.0 5W RMS
# 19.99
# Logitech Wireless Desktop MK710
# 78.99
# Logitech Wireless Presenter R400
# 19.99
# Logitech G635 Auriculares Gaming LightSync 7.1 Reacondicionado
# 109.45
# Logitech K380 Teclado Bluetooth Multi-Device Blanco Reacondicionado
# 37.4
# Logitech StreamCam Webcam USB-C Full HD Blanca Reacondicionado
# 146.35
# Logitech G332 Special Edition Auriculares Gaming Reacondicionado
# 32.5
# Logitech StreamCam Webcam USB-C Full HD Negra Reacondicionado
# 148.9
# Logitech B525 Webcam HD  Reacondicionado
# 65.45
# Logitech 603 Ratón Gaming Inalámbrico 12000DPI Reacondicionado
# 56.2
# Logitech Craft Teclado Inalámbrico con Disco Selector Reacondicionado
# 146.45
# Logitech StreamCam Webcam USB-C Full HD Blanca
# 158.99
# Logitech StreamCam Webcam USB-C Full HD Negra
# 158.99
# Logitech G Alfombrilla con Sistema de Carga Inalámbrica Powerplay para Logitech G703/G903/G502
# 118.99
# Logitech C920s Pro Webcam
# 94
# Logitech MX Sound Altavoces Bluetooth 12W
# 89.99
# Logitech Circle 2 Alargador para Cámara de Seguridad
# 49.99
# Logitech Slim Folio Pro Funda con Teclado Bluetooth para Apple iPad Pro de 12.9 (3ª Generación)
# 121.33
# Logitech Expansion Meetup Micrófono Adicional para Meetup Reacondicionado
# 128.65
# Logitech Pro Flight Rudder Pedals Pedales de Timón de Vuelo
# 138.99
# Logitech Pro Flight Throttle Quadrant Cuadrante de Aceleración
# 79.98
# Logitech Pro Flight Yoke System Sistema de Control de Vuelo
# 158.99
# Logitech Doodle Collection M238 Sneaker Ratón Inalámbrico Ambidiestro 1000DPI Azul
# 16
# Logitech Doodle Collection M238 Champion Ratón Inalámbrico Ambidiestro 1000DPI Rojo
# 17.99
# Logitech Doodle Collection M238 Ratón Inalámbrico Ambidiestro 1000DPI Amarillo
# 17.99
# 30
# Logitech Expansion Meetup Micrófono Adicional para Meetup
# 219
# Logitech H540 Auriculares Negros
# 45
# Logitech Unifying Receptor Inalámbrico Ratones y Teclados USB
# 15.95
# Logitech G935 Auriculares Gaming Inalámbricos LightSync 7.1
# 169
# Logitech G332 Auriculares Gaming
# 59.98
# Logitech Craft Teclado Inalámbrico con Disco Selector
# 158.99
# Logitech G Saitek X52 Pro Flight Control System Controlador Simulador de Vuelo
# 199
# Logitech G513 Teclado Mecánico Gaming Retroiluminado Switch Romer-G Táctil
# 179
# Logitech Brio Stream Cámara Web Profesional para Streaming HD 4K
# 199
# Logitech H570e Auriculares con Micrófono
# 49.99
# Logitech B525 Webcam HD
# 99
# Auriculares con Micrófono Logitech H151
# 18.98
# Altavoces 2.1 Bluetooth Logitech Z537 Negro
# 95.99
# Logitech G433 Auriculares Gaming Negros
# 92.99
# Logitech G933 Artemis Spectrum Gaming 7.1 Inalámbricos Blancos
# 199
# Logitech Slim Combo Funda con Teclado Inalámbrico Negro para  iPad Pro de 10.5"
# 132.98
# Logitech Slim Folio Funda con Teclado Bluetooth Negro para iPad 2017/2018
# 82.98
# Logitech G413 Teclado Mecánico Gaming
# 79.98
# Logitech K375S Teclado Inálambrico Multidispositivo
# 37.99
# Logitech MX Master 2S Ratón Inalámbrico Azul 1000DPI
# 86.99
# Logitech H570E Auriculares con Micrófono Negros
# 47
# Logitech Brio Webcam 4k UltraHD
# 329
# Logitech Webcam C170 5MP
# 17.98
# Logitech Webcam C925e HD
# 78.99
# Logitech Wireless Combo MK235 Reacondicionado
# 18.85
# Wheel Stand Pro Deluxe For Logitech G25/G27/G29/G920
# 101
# Newskill Byakko V2 Soporte de Volante Profesional para Logitech/Thrustmaster Refurbished
# 75
# Newskill Byakko V2 Soporte de Volante Profesional para Logitech/Thrustmaster
# 119.98
# Mayflash Magic-NS Adaptador para Mandos PS4/PS3/PC
# 29.49
# Mayflash Magic-NS Adaptador para Mandos NeoGeo Mini/Nintendo Switch/PC
# 22.69
# 17
# STM Dux Plus Duo Funda Azul para iPad 7º Generación
# 63.67
# STM Dux Plus Duo Funda Roja para iPad 7º Generación
# 49.99
# STM Dux Plus Duo Funda Negra para iPad 7º Generación
# 63.67
# Playseat Forza Motorsport
# 369
# Playseat Evolution PlayStation
# 339.99
# Playseat Evolution Alcantara PRO
# 379
# Playseat Evolution Alcantara PRO Reacondicionado
# 325.65
# Playseat Challenge PlayStation
# 248.99
# Playseat Evolution Blanco
# 278.99
# Playseat Evolution Negro
# 278.99
# Playseat Evolution Alcántara
# 299
# Playseat Gran Turismo
# 369
# Wheel Stand Pro Deluxe For Thrustmaster T300RS / TX Series
# 110.99
# Playseat DIRT
# 369
# Playseat Project Cars
# 369
# Playseat Project Cars Reacondicionado
# 325.65
# Metronic Antena Interior UHF HD Digitech 2.1 con filtro 4G Negra
# 19
# 0
# 0

# %%
asd = input('')
# Out:
#  hola

# %%
asd
# Out:
# 'hola'
